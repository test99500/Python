# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\_pydevd_bundle\pydevd_cython_wrapper.py in <module>
#       7     try:
# ----> 8         from _pydevd_bundle_ext import pydevd_cython as mod
#       9
#
# ModuleNotFoundError: No module named '_pydevd_bundle_ext'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\_pydevd_bundle\pydevd_cython_wrapper.py in <module>
#      10     except ImportError:
# ---> 11         from _pydevd_bundle import pydevd_cython as mod
#      12
#
# ImportError: cannot import name 'pydevd_cython' from '_pydevd_bundle' (C:\Users\ted10014\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\_pydevd_bundle\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39080\3607238440.py in <module>
#       7 remove_imported_pydev_package()
#       8 import pydev_jupyter_utils
# ----> 9 pydev_jupyter_utils.attach_to_debugger(65124)
#
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_utils.py in attach_to_debugger(debugger_port)
#      72     ipython_shell = get_ipython()
#      73
# ---> 74     import pydevd
#      75     from _pydev_bundle import pydev_localhost
#      76
#
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\pydevd.py in <module>
#      53 from _pydevd_bundle.pydevd_frame_utils import add_exception_to_frame, remove_exception_from_frame
#      54 from _pydevd_bundle.pydevd_kill_all_pydevd_threads import kill_all_pydev_threads
# ---> 55 from _pydevd_bundle.pydevd_trace_dispatch import (
#      56     trace_dispatch as _trace_dispatch, global_cache_skips, global_cache_frame_skips, show_tracing_warning)
#      57 from _pydevd_frame_eval.pydevd_frame_eval_main import (
#
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\_pydevd_bundle\pydevd_trace_dispatch.py in <module>
#      53     # Regular: use fallback if not found and give message to user
#      54     try:
# ---> 55         from _pydevd_bundle.pydevd_cython_wrapper import trace_dispatch as _trace_dispatch, global_cache_skips, global_cache_frame_skips, fix_top_level_trace_and_get_trace_func
#      56         def trace_dispatch(py_db, frame, event, arg):
#      57             if _trace_dispatch is None:
#
# ~\AppData\Local\JetBrains\Toolbox\apps\IDEA-U\ch-0\213.6777.52.plugins\python\helpers\pydev\_pydevd_bundle\pydevd_cython_wrapper.py in <module>
#      33     mod_name = 'pydevd_cython_%s_%s%s_%s' % (sys.platform, sys.version_info[0], sys.version_info[1], plat)
#      34     check_name = '_pydevd_bundle.%s' % (mod_name,)
# ---> 35     mod = getattr(__import__(check_name), mod_name)
#      36
#      37 # Regardless of how it was found, make sure it's later available as the
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
import thinkdsp
import matplotlib.pyplot as plt

cos_signal = thinkdsp.CosSignal(freq=440, amp=1.0, offset=0)
sin_sigal = thinkdsp.SinSignal(freq=880, amp=0.5, offset=0)

mix = sin_sigal + cos_signal

wave = mix.make_wave(duration=0.5, start=0, framerate=11025)

wave.plot()

plt.show()

# %%
cos_signal.plot()

plt.xlabel(xlabel='Time (s)')

plt.show()

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*3)

segment.plot()

plt.xlabel(xlabel='Time (s)')

plt.show()
